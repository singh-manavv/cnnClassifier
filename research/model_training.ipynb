# %%
import os

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\Manav\\Projects\\cnnClassifier'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_is_augmentation: bool
    params_image_size: list

@dataclass(frozen=True)
class PrepareCallbacksConfig:
    root_dir : Path
    tensorboard_root_log_dir: Path
    checkpoint_model_filepath: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils import *
import tensorflow as tf
import time

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    
    def get_prepare_callbacks_config(self) -> PrepareCallbacksConfig:
        config = self.config.prepare_callbacks
        model_ckpt_dir = os.path.dirname(config.checkpoint_model_filepath)
        create_directories([
            Path(model_ckpt_dir),
            Path(config.tensorboard_root_log_dir)
        ])

        prepare_callback_config = PrepareCallbacksConfig(
            root_dir=Path(config.root_dir),
            tensorboard_root_log_dir=Path(config.tensorboard_root_log_dir),
            checkpoint_model_filepath=Path(config.checkpoint_model_filepath)
        )

        return prepare_callback_config
    

    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params
        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "PetImages")
        create_directories([
            Path(training.root_dir)
        ])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
class PrepareCallback:
    def __init__(self, config: PrepareCallbacksConfig):
        self.config = config

    
    @property
    def _create_tb_callbacks(self):
        timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
        tb_running_log_dir = os.path.join(
            self.config.tensorboard_root_log_dir,
            f"tb_logs_at_{timestamp}",
        )
        return tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)
    

    @property
    def _create_ckpt_callbacks(self):
        return tf.keras.callbacks.ModelCheckpoint(
            filepath=self.config.checkpoint_model_filepath,
            save_best_only=True
        )


    def get_tb_ckpt_callbacks(self):
        return [
            self._create_tb_callbacks,
            self._create_ckpt_callbacks
        ]

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config
        
    def get_base_model(self):
        self.model = tf.keras.models.load_model(
            self.config.updated_base_model_path
        )
    
    def train_valid_generator(self):
        
        datagenerator_kwargs = dict(
            rescale= 1./255,
            validation_split = 0.20
        )
        
        dataflow_kwargs = dict(
            target_size = self.config.params_image_size[:-1],
            batch_size = self.config.params_batch_size,
            interpolation = 'bilinear'
        )
        
        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )
        
        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory= self.config.training_data,
            subset='validation',
            shuffle= False,
            **dataflow_kwargs
        )
        
        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator
            
        
        self.train_generator = train_datagenerator.flow_from_directory(
            directory= self.config.training_data,
            subset='training',
            **dataflow_kwargs
        )
        
    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)
        
    def train(self, callbacks_list: list):
        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size
        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size
        
        self.model.fit(
            self.train_generator,
            epochs= self.config.params_epochs,
            steps_per_epoch = self.steps_per_epoch,
            validation_steps = self.validation_steps,
            validation_data = self.valid_generator,
            callbacks = callbacks_list
        )
        
        self.save_model(
            path = self.config.trained_model_path,
            model = self.model
        )

# %%
try:
    config = ConfigurationManager()
    prepare_callbacks_config = config.get_prepare_callbacks_config()
    prepare_callbacks = PrepareCallback(config=prepare_callbacks_config)
    callback_list = prepare_callbacks.get_tb_ckpt_callbacks()
    
    training_config = config.get_training_config()
    training = Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train(
        callbacks_list= callback_list
    )
except Exception as e:
    raise e
# Out:
# [2024-03-29 17:11:25,203: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-03-29 17:11:25,210: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-03-29 17:11:25,211: INFO: common: created directory at: artifacts]
# [2024-03-29 17:11:25,212: INFO: common: created directory at: artifacts\prepare_callbacks\checkpoint_dir]
# [2024-03-29 17:11:25,213: INFO: common: created directory at: artifacts\prepare_callbacks\tensorboard_log_dir]
# [2024-03-29 17:11:25,215: INFO: common: created directory at: artifacts\training]
# Found 78 images belonging to 2 classes.
# Found 318 images belonging to 2 classes.
# Epoch 1/100
# 19/19 [==============================] - 4s 175ms/step - loss: 16.3467 - accuracy: 0.4868 - val_loss: 19.6700 - val_accuracy: 0.3906
# Epoch 2/100
# 19/19 [==============================] - 3s 180ms/step - loss: 15.2868 - accuracy: 0.5331 - val_loss: 5.6136 - val_accuracy: 0.3906
# Epoch 3/100
# 19/19 [==============================] - 3s 181ms/step - loss: 13.0530 - accuracy: 0.5364 - val_loss: 8.1683 - val_accuracy: 0.6094
# Epoch 4/100
# 19/19 [==============================] - 3s 167ms/step - loss: 12.3785 - accuracy: 0.5497 - val_loss: 17.0139 - val_accuracy: 0.6094
# Epoch 5/100
# 19/19 [==============================] - 3s 158ms/step - loss: 15.9862 - accuracy: 0.4801 - val_loss: 16.0551 - val_accuracy: 0.3906
# Epoch 6/100
# 19/19 [==============================] - 3s 160ms/step - loss: 13.6941 - accuracy: 0.5232 - val_loss: 2.6205 - val_accuracy: 0.7812
# Epoch 7/100
# 19/19 [==============================] - 3s 159ms/step - loss: 9.3184 - accuracy: 0.5728 - val_loss: 26.3402 - val_accuracy: 0.3906
# Epoch 8/100
# 19/19 [==============================] - 3s 165ms/step - loss: 8.7991 - accuracy: 0.6457 - val_loss: 6.1261 - val_accuracy: 0.5156
# Epoch 9/100
# 19/19 [==============================] - 3s 158ms/step - loss: 8.6964 - accuracy: 0.6093 - val_loss: 5.7424 - val_accuracy: 0.7031
# Epoch 10/100
# 19/19 [==============================] - 3s 163ms/step - loss: 8.0665 - accuracy: 0.6358 - val_loss: 5.7770 - val_accuracy: 0.5625
# Epoch 11/100
# 19/19 [==============================] - 3s 154ms/step - loss: 8.9953 - accuracy: 0.5993 - val_loss: 18.4415 - val_accuracy: 0.3906
# Epoch 12/100
# 19/19 [==============================] - 3s 152ms/step - loss: 7.7206 - accuracy: 0.6424 - val_loss: 10.3329 - val_accuracy: 0.4531
# Epoch 13/100
# 19/19 [==============================] - 3s 149ms/step - loss: 4.3562 - accuracy: 0.6887 - val_loss: 7.8368 - val_accuracy: 0.5000
# Epoch 14/100
# 19/19 [==============================] - 3s 166ms/step - loss: 9.1960 - accuracy: 0.5927 - val_loss: 19.0684 - val_accuracy: 0.3906
# Epoch 15/100
# 19/19 [==============================] - 3s 163ms/step - loss: 6.5072 - accuracy: 0.6457 - val_loss: 1.4474 - val_accuracy: 0.8750
# Epoch 16/100
# 19/19 [==============================] - 3s 163ms/step - loss: 4.5154 - accuracy: 0.7185 - val_loss: 3.1892 - val_accuracy: 0.7500
# Epoch 17/100
# 19/19 [==============================] - 3s 170ms/step - loss: 2.5025 - accuracy: 0.8079 - val_loss: 2.1402 - val_accuracy: 0.8594
# Epoch 18/100
# 19/19 [==============================] - 3s 149ms/step - loss: 4.3935 - accuracy: 0.7417 - val_loss: 3.2814 - val_accuracy: 0.7656
# Epoch 19/100
# 19/19 [==============================] - 3s 157ms/step - loss: 5.2331 - accuracy: 0.7185 - val_loss: 1.3021 - val_accuracy: 0.8750
# Epoch 20/100
# 19/19 [==============================] - 3s 154ms/step - loss: 2.2147 - accuracy: 0.8146 - val_loss: 1.6370 - val_accuracy: 0.7969
# Epoch 21/100
# 19/19 [==============================] - 3s 157ms/step - loss: 6.8717 - accuracy: 0.6159 - val_loss: 20.8760 - val_accuracy: 0.3906
# Epoch 22/100
# 19/19 [==============================] - 3s 164ms/step - loss: 7.6851 - accuracy: 0.6159 - val_loss: 1.7906 - val_accuracy: 0.8594
# Epoch 23/100
# 19/19 [==============================] - 3s 157ms/step - loss: 3.2744 - accuracy: 0.7483 - val_loss: 2.3093 - val_accuracy: 0.8438
# Epoch 24/100
# 19/19 [==============================] - 3s 157ms/step - loss: 2.6320 - accuracy: 0.8179 - val_loss: 2.0592 - val_accuracy: 0.7969
# Epoch 25/100
# 19/19 [==============================] - 3s 156ms/step - loss: 3.3131 - accuracy: 0.7550 - val_loss: 3.3761 - val_accuracy: 0.7656
# Epoch 26/100
# 19/19 [==============================] - 3s 159ms/step - loss: 2.4617 - accuracy: 0.7881 - val_loss: 6.6186 - val_accuracy: 0.7188
# Epoch 27/100
# 19/19 [==============================] - 3s 158ms/step - loss: 3.2392 - accuracy: 0.7417 - val_loss: 16.1695 - val_accuracy: 0.4375
# Epoch 28/100
# 19/19 [==============================] - 3s 156ms/step - loss: 4.1814 - accuracy: 0.7384 - val_loss: 6.2175 - val_accuracy: 0.6562
# Epoch 29/100
# 19/19 [==============================] - 3s 157ms/step - loss: 3.2598 - accuracy: 0.7450 - val_loss: 14.1346 - val_accuracy: 0.4531
# Epoch 30/100
# 19/19 [==============================] - 3s 164ms/step - loss: 3.4472 - accuracy: 0.7483 - val_loss: 3.1091 - val_accuracy: 0.7500
# Epoch 31/100
# 19/19 [==============================] - 3s 147ms/step - loss: 3.9695 - accuracy: 0.7550 - val_loss: 1.9586 - val_accuracy: 0.7969
# Epoch 32/100
# 19/19 [==============================] - 3s 170ms/step - loss: 3.8240 - accuracy: 0.7152 - val_loss: 1.0228 - val_accuracy: 0.8906
# Epoch 33/100
# 19/19 [==============================] - 3s 170ms/step - loss: 2.9001 - accuracy: 0.7763 - val_loss: 8.6161 - val_accuracy: 0.5625
# Epoch 34/100
# 19/19 [==============================] - 3s 158ms/step - loss: 2.7877 - accuracy: 0.7748 - val_loss: 4.0659 - val_accuracy: 0.7188
# Epoch 35/100
# 19/19 [==============================] - 3s 159ms/step - loss: 6.4376 - accuracy: 0.6689 - val_loss: 1.2958 - val_accuracy: 0.8281
# Epoch 36/100
# 19/19 [==============================] - 3s 163ms/step - loss: 4.3922 - accuracy: 0.7401 - val_loss: 5.4511 - val_accuracy: 0.6875
# Epoch 37/100
# 19/19 [==============================] - 3s 153ms/step - loss: 5.4987 - accuracy: 0.6457 - val_loss: 2.2968 - val_accuracy: 0.8281
# Epoch 38/100
# 19/19 [==============================] - 3s 152ms/step - loss: 2.9311 - accuracy: 0.7947 - val_loss: 2.8989 - val_accuracy: 0.7969
# Epoch 39/100
# 19/19 [==============================] - 4s 188ms/step - loss: 3.4590 - accuracy: 0.7583 - val_loss: 1.2779 - val_accuracy: 0.8594
# Epoch 40/100
# 19/19 [==============================] - 3s 179ms/step - loss: 3.1552 - accuracy: 0.7616 - val_loss: 1.8348 - val_accuracy: 0.8594
# Epoch 41/100
# 19/19 [==============================] - 3s 154ms/step - loss: 2.8667 - accuracy: 0.7748 - val_loss: 2.2003 - val_accuracy: 0.8281
# Epoch 42/100
# 19/19 [==============================] - 3s 155ms/step - loss: 3.4531 - accuracy: 0.7715 - val_loss: 1.8740 - val_accuracy: 0.7969
# Epoch 43/100
# 19/19 [==============================] - 3s 149ms/step - loss: 2.5330 - accuracy: 0.7550 - val_loss: 10.3305 - val_accuracy: 0.5625
# Epoch 44/100
# 19/19 [==============================] - 3s 147ms/step - loss: 2.3418 - accuracy: 0.8344 - val_loss: 2.1579 - val_accuracy: 0.7969
# Epoch 45/100
# 19/19 [==============================] - 3s 148ms/step - loss: 1.8138 - accuracy: 0.8311 - val_loss: 2.0207 - val_accuracy: 0.8281
# Epoch 46/100
# 19/19 [==============================] - 3s 161ms/step - loss: 4.5362 - accuracy: 0.7185 - val_loss: 1.2511 - val_accuracy: 0.8594
# Epoch 47/100
# 19/19 [==============================] - 3s 175ms/step - loss: 2.1603 - accuracy: 0.8046 - val_loss: 2.4301 - val_accuracy: 0.7969
# Epoch 48/100
# 19/19 [==============================] - 3s 150ms/step - loss: 3.4777 - accuracy: 0.7881 - val_loss: 1.1319 - val_accuracy: 0.8906
# Epoch 49/100
# 19/19 [==============================] - 3s 164ms/step - loss: 2.9533 - accuracy: 0.7649 - val_loss: 1.7366 - val_accuracy: 0.8125
# Epoch 50/100
# 19/19 [==============================] - 3s 163ms/step - loss: 1.6767 - accuracy: 0.8477 - val_loss: 1.3054 - val_accuracy: 0.8906
# Epoch 51/100
# 19/19 [==============================] - 3s 153ms/step - loss: 1.6076 - accuracy: 0.8212 - val_loss: 1.6606 - val_accuracy: 0.8125
# Epoch 52/100
# 19/19 [==============================] - 3s 151ms/step - loss: 1.1437 - accuracy: 0.8609 - val_loss: 3.4997 - val_accuracy: 0.7656
# Epoch 53/100
# 19/19 [==============================] - 4s 183ms/step - loss: 3.1467 - accuracy: 0.7947 - val_loss: 1.7076 - val_accuracy: 0.8125
# Epoch 54/100
# 19/19 [==============================] - 3s 165ms/step - loss: 3.0790 - accuracy: 0.7815 - val_loss: 2.5371 - val_accuracy: 0.8125
# Epoch 55/100
# 19/19 [==============================] - 3s 157ms/step - loss: 1.6555 - accuracy: 0.8477 - val_loss: 1.2917 - val_accuracy: 0.8594
# Epoch 56/100
# 19/19 [==============================] - 3s 158ms/step - loss: 1.1664 - accuracy: 0.8709 - val_loss: 1.0205 - val_accuracy: 0.8594
# Epoch 57/100
# 19/19 [==============================] - 3s 158ms/step - loss: 1.0489 - accuracy: 0.8742 - val_loss: 2.8131 - val_accuracy: 0.7656
# Epoch 58/100
# 19/19 [==============================] - 3s 157ms/step - loss: 1.2481 - accuracy: 0.8775 - val_loss: 1.1304 - val_accuracy: 0.8594
# Epoch 59/100
# 19/19 [==============================] - 3s 160ms/step - loss: 1.6103 - accuracy: 0.8411 - val_loss: 2.0922 - val_accuracy: 0.8125
# Epoch 60/100
# 19/19 [==============================] - 3s 158ms/step - loss: 2.8902 - accuracy: 0.7682 - val_loss: 1.1554 - val_accuracy: 0.8594
# Epoch 61/100
# 19/19 [==============================] - 3s 166ms/step - loss: 3.9770 - accuracy: 0.7781 - val_loss: 2.0271 - val_accuracy: 0.7969
# Epoch 62/100
# 19/19 [==============================] - 3s 164ms/step - loss: 2.1603 - accuracy: 0.8179 - val_loss: 2.0422 - val_accuracy: 0.8125
# Epoch 63/100
# 19/19 [==============================] - 3s 167ms/step - loss: 3.9667 - accuracy: 0.7252 - val_loss: 0.9855 - val_accuracy: 0.8906
# Epoch 64/100
# 19/19 [==============================] - 3s 148ms/step - loss: 1.0244 - accuracy: 0.8974 - val_loss: 2.5298 - val_accuracy: 0.7656
# Epoch 65/100
# 19/19 [==============================] - 3s 147ms/step - loss: 2.1630 - accuracy: 0.8079 - val_loss: 1.1432 - val_accuracy: 0.8594
# Epoch 66/100
# 19/19 [==============================] - 3s 170ms/step - loss: 1.8826 - accuracy: 0.8576 - val_loss: 0.9681 - val_accuracy: 0.8750
# Epoch 67/100
# 19/19 [==============================] - 3s 149ms/step - loss: 0.9508 - accuracy: 0.8841 - val_loss: 1.2947 - val_accuracy: 0.8281
# Epoch 68/100
# 19/19 [==============================] - 3s 161ms/step - loss: 1.9115 - accuracy: 0.8245 - val_loss: 1.4179 - val_accuracy: 0.8281
# Epoch 69/100
# 19/19 [==============================] - 3s 163ms/step - loss: 1.3570 - accuracy: 0.8510 - val_loss: 1.2226 - val_accuracy: 0.8438
# Epoch 70/100
# 19/19 [==============================] - 3s 176ms/step - loss: 2.0460 - accuracy: 0.8278 - val_loss: 1.1652 - val_accuracy: 0.8438
# Epoch 71/100
# 19/19 [==============================] - 3s 170ms/step - loss: 1.8907 - accuracy: 0.8079 - val_loss: 5.6662 - val_accuracy: 0.6719
# Epoch 72/100
# 19/19 [==============================] - 3s 158ms/step - loss: 1.4134 - accuracy: 0.8510 - val_loss: 1.0276 - val_accuracy: 0.8594
# Epoch 73/100
# 19/19 [==============================] - 3s 159ms/step - loss: 1.3036 - accuracy: 0.8709 - val_loss: 1.1749 - val_accuracy: 0.8906
# Epoch 74/100
# 19/19 [==============================] - 3s 177ms/step - loss: 1.6106 - accuracy: 0.8576 - val_loss: 1.4933 - val_accuracy: 0.8281
# Epoch 75/100
# 19/19 [==============================] - 3s 158ms/step - loss: 1.2745 - accuracy: 0.8709 - val_loss: 1.9920 - val_accuracy: 0.7656
# Epoch 76/100
# 19/19 [==============================] - 3s 165ms/step - loss: 1.7025 - accuracy: 0.8543 - val_loss: 0.8856 - val_accuracy: 0.9062
# Epoch 77/100
# 19/19 [==============================] - 3s 149ms/step - loss: 0.6156 - accuracy: 0.9046 - val_loss: 0.9011 - val_accuracy: 0.8906
# Epoch 78/100
# 19/19 [==============================] - 3s 155ms/step - loss: 1.5838 - accuracy: 0.8477 - val_loss: 0.8809 - val_accuracy: 0.9062
# Epoch 79/100
# 19/19 [==============================] - 3s 148ms/step - loss: 2.6655 - accuracy: 0.7848 - val_loss: 8.1273 - val_accuracy: 0.7188
# Epoch 80/100
# 19/19 [==============================] - 4s 193ms/step - loss: 2.6045 - accuracy: 0.8212 - val_loss: 1.0191 - val_accuracy: 0.8750
# Epoch 81/100
# 19/19 [==============================] - 3s 151ms/step - loss: 0.7557 - accuracy: 0.9106 - val_loss: 3.4397 - val_accuracy: 0.7500
# Epoch 82/100
# 19/19 [==============================] - 3s 154ms/step - loss: 1.1283 - accuracy: 0.8940 - val_loss: 1.3180 - val_accuracy: 0.8281
# Epoch 83/100
# 19/19 [==============================] - 3s 158ms/step - loss: 1.4224 - accuracy: 0.8377 - val_loss: 8.3593 - val_accuracy: 0.6094
# Epoch 84/100
# 19/19 [==============================] - 3s 157ms/step - loss: 2.9453 - accuracy: 0.7781 - val_loss: 4.4759 - val_accuracy: 0.7031
# Epoch 85/100
# 19/19 [==============================] - 3s 178ms/step - loss: 2.6776 - accuracy: 0.7715 - val_loss: 2.7971 - val_accuracy: 0.7656
# Epoch 86/100
# 19/19 [==============================] - 3s 153ms/step - loss: 2.7183 - accuracy: 0.7848 - val_loss: 14.5112 - val_accuracy: 0.5156
# Epoch 87/100
# 19/19 [==============================] - 3s 151ms/step - loss: 3.8098 - accuracy: 0.7384 - val_loss: 5.7396 - val_accuracy: 0.7656
# Epoch 88/100
# 19/19 [==============================] - 3s 159ms/step - loss: 4.9525 - accuracy: 0.7252 - val_loss: 2.7294 - val_accuracy: 0.7656
# Epoch 89/100
# 19/19 [==============================] - 3s 149ms/step - loss: 1.0424 - accuracy: 0.8411 - val_loss: 1.8679 - val_accuracy: 0.8438
# Epoch 90/100
# 19/19 [==============================] - 3s 154ms/step - loss: 0.6646 - accuracy: 0.9073 - val_loss: 5.5497 - val_accuracy: 0.6875
# Epoch 91/100
# 19/19 [==============================] - 3s 164ms/step - loss: 3.1787 - accuracy: 0.7815 - val_loss: 1.0145 - val_accuracy: 0.8906
# Epoch 92/100
# 19/19 [==============================] - 3s 170ms/step - loss: 1.9394 - accuracy: 0.8179 - val_loss: 1.3104 - val_accuracy: 0.8750
# Epoch 93/100
# 19/19 [==============================] - 3s 163ms/step - loss: 1.0957 - accuracy: 0.8841 - val_loss: 1.6935 - val_accuracy: 0.8438
# Epoch 94/100
# 19/19 [==============================] - 3s 165ms/step - loss: 1.0105 - accuracy: 0.8874 - val_loss: 2.2270 - val_accuracy: 0.7812
# Epoch 95/100
# 19/19 [==============================] - 3s 163ms/step - loss: 1.9017 - accuracy: 0.8278 - val_loss: 1.1780 - val_accuracy: 0.8750
# Epoch 96/100
# 19/19 [==============================] - 3s 159ms/step - loss: 1.8221 - accuracy: 0.8444 - val_loss: 1.3193 - val_accuracy: 0.8750
# Epoch 97/100
# 19/19 [==============================] - 3s 159ms/step - loss: 2.6088 - accuracy: 0.7748 - val_loss: 8.8418 - val_accuracy: 0.6406
# Epoch 98/100
# 19/19 [==============================] - 3s 157ms/step - loss: 2.9828 - accuracy: 0.7649 - val_loss: 1.5278 - val_accuracy: 0.8594
# Epoch 99/100
# 19/19 [==============================] - 3s 163ms/step - loss: 1.1562 - accuracy: 0.8709 - val_loss: 1.0602 - val_accuracy: 0.8750
# Epoch 100/100
# 19/19 [==============================] - 3s 157ms/step - loss: 0.7627 - accuracy: 0.8940 - val_loss: 2.4502 - val_accuracy: 0.7656
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
